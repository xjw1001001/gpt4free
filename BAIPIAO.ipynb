# %%
import pandas as pd
from gpt4free import forefront
prompt_head = '''I have the following [social association types]:
[c_assoc_type_id] 	[c_assoc_type_desc_chn]

0101	社會關係（籠統）
0102	同為……之成員
0103	社會交際
0202	師生關係
0203	學術交往
0204	學術主題相近
0205	同為……之成員
0206	學術襄助
0207	文學藝術交往
0208	學術攻訐
0301	朋友關係（籠統）
0401	政治關係（籠統）
0402	官場關係（平級）
0403	官場關係（下屬）
0404	官場關係（上司）
0405	政治奧援
0406	薦舉保任
0407	政治對抗
0501	著述關係（籠統）
0502	記詠文字
0503	墓誌文字
0504	序跋文字
0505	禮儀文字
0506	傳記文字
0507	論說文字
0508	箴銘文字
0509	書札文字
0510	應酬文字
0601	軍事關係（籠統）
0602	軍事支持
0603	軍事對抗
0701	醫療關係（籠統）
0801	宗教關係（籠統）
0901	家庭關係（籠統）
1001	財務關係（籠統）

I will provide you with the biographies of individuals from the Song dynasty. 
For each of the biography, they contain at least two names: [a], [b], [c], [d], etc.

After you read a biography of [a], please tell me the social association code(s) between [a] and others, namely between [a] and [b]; [a] and [c]; [a] and [d]; etc. Don't use any knowledge outside of the biography provided. The information that you need to capture to identify the social association but will be very close to the persons' name.

In addition, the relationship between two people might fall into multiple categories. For instance, they might have a 師生關係, as well as a 官場關係. Thus, please provide all the ones that apply; please also and rank them (more important ones first). 

You will also have to put your [reasoning] for choosing these associations types, and judging whether they are positive or negative. Use English when possible; be concise.

The output scheme should be a table like this:

|[task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
| -- | -- | -- | -- | -- | -- | -- |
| task_number | [a] | [b] | c_assoc_type_id_1; c_assoc_type_id_2; etc. | c_assoc_type_desc_chn_1; c_assoc_type_desc_chn_2; etc. | positive/negative | reason |
| task_number | [a] | [c] | c_assoc_type_id_1; c_assoc_type_id_2; etc. | c_assoc_type_desc_chn_1; c_assoc_type_desc_chn_2; etc. | positive/negative | reason |

Before you work on the task, I will provide you with two examples that help you understand.

For task_number 900001, the biography of 徐几 is “徐几，字字与，号进斋，崇安人。博通经史，尤精于易。景定间与何基同以布衣召补迪功郎，添差建宁府教授，兼建安书院山长，撰经义以训式多士。” The biography mentions two people, [a] 徐几 and [b] 何基. The assoc_code for the relationship between 徐几 and 何基 is 0402; it is a positive relationship. 
For task_number 900002, the biography of 丁希亮 is “丁希亮，(1156～1192)，字少詹，黄巖人，世雄堂弟。从叶适学，又从陈亮、吕祖谦游。名言奥义，贯穿殆尽。论事深眇，皆有方幅。有丁少詹集(按县志著梅巖文集数十卷)。卒于绍熙三年，年四十七(按墓志作绍兴三年卒，以叶适生平推考之，应是绍熙之误)。” The biography mentions [a] 丁希亮, [b] 叶适, [c] 陈亮, [d] 吕祖. The relationship between 丁希亮 and 叶适 is 0202; 0203; 0206; positive.  The relationship between 丁希亮 and 陈亮 is 0203; 0206. The relationship between 丁希亮 and 吕祖 is 0207; 0301; positive.

If you understand, then work on these biographies.

'''


"""
[1] Task number is [XXXX]. The biography is “[XXXX]"。 It mentions [a] XXXX, [B] XXXX, [C] XXXX, [D] XXXX.
[2] Task number is [XXXX]. The biography is “[XXXX]"。 It mentions [a] XXXX, [B] XXXX, [C] XXXX, [D] XXXX.
[3] Task number is [XXXX]. The biography is “[XXXX]"。 It mentions [a] XXXX, [B] XXXX, [C] XXXX, [D] XXXX.
[4] Task number is [XXXX]. The biography is “[XXXX]"。 It mentions [a] XXXX, [B] XXXX, [C] XXXX, [D] XXXX.
"""
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# '\n[1] Task number is [XXXX]. The biography is “[XXXX]"。 It mentions [a] XXXX, [B] XXXX, [C] XXXX, [D] XXXX.\n[2] Task number is [XXXX]. The biography is “[XXXX]"。 It mentions [a] XXXX, [B] XXXX, [C] XXXX, [D] XXXX.\n[3] Task number is [XXXX]. The biography is “[XXXX]"。 It mentions [a] XXXX, [B] XXXX, [C] XXXX, [D] XXXX.\n[4] Task number is [XXXX]. The biography is “[XXXX]"。 It mentions [a] XXXX, [B] XXXX, [C] XXXX, [D] XXXX.\n'

# %%
len(paragraphs)
# Out:
# 4167

# %%
import time
import gpt4free
from gpt4free import Provider, quora, forefront
import os
start_time = time.time()
folder_path = './download_result/'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
result = []

number_of_inputs = 4
df1 = pd.read_csv('song.csv')
df1 = df1[df1['name_number'] >= 2]
paragraphs = df1.values.tolist()

for i in range(0, 1000, number_of_inputs):
    prompt_out = prompt_head
    paragraph_list = paragraphs[i:i+number_of_inputs]
    for paragraph in paragraph_list:
        paragraph_number = paragraph[0]
        text = paragraph[1]
        people_num = paragraph[3]
        people = paragraph[2].split(",")
        alphabet = "abcdefghi"
        prompt2 = ' it mentions '
        for i in range(people_num):
            prompt2 += "[" + alphabet[i] + "]" + '"' + people[i] + '", '
        prompt2 = prompt2[:-2]
        prompt = 'Task number is {}. The biography is "{}",'.format(paragraph_number, text)
        prompt_out += prompt + prompt2 + "\n"
    
    gpt_result = []
    if os.path.isfile(folder_path+'id' + str(paragraph_number) + '.txt'):
            continue
    while True:
        try:  
            #time.sleep(1)
            token = forefront.Account.create(logging=False)
            print("Trying to evaluate paragraph {}".format(paragraph_number))
            response = gpt4free.Completion.create(
                Provider.ForeFront, prompt=prompt_out, model='gpt-4', token=token
            )
            if len(response) >= 15:
                with open(folder_path+'id' + str(paragraph_number) + '.txt', 'w') as f:
                    f.write(response)
                break
        except Exception as e: # work on python 3.x
            print(e)
            if str(e) == "HTTP 429":
                print("429, need to sleep for a while")
                time.sleep(100)
            if str(e) == "HTTP 422":
                print("Need to retry, 422")
                time.sleep(2)
            
    
    result.append(response)
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# HTTP 422
# Need to retry, 422
# Trying to evaluate paragraph 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18100/1985815731.py in <module>
#      39             token = forefront.Account.create(logging=False)
#      40             print("Trying to evaluate paragraph {}".format(paragraph_number))
# ---> 41             response = gpt4free.Completion.create(
#      42                 Provider.ForeFront, prompt=prompt_out, model='gpt-4', token=token
#      43             )
#
# ~\Desktop\gpt4free\gpt4free\__init__.py in create(provider, prompt, **kwargs)
#      38             return Completion.__you_service(prompt, **kwargs)
#      39         elif provider == Provider.ForeFront:
# ---> 40             return Completion.__fore_front_service(prompt, **kwargs)
#      41         elif provider == Provider.Theb:
# ...

# %%
# Out:
# Exception

# %% [markdown]
# |task no|person 1|person 2|assoc_code|assoc|assoc_chn|positive/negative relationship| reason|
# | -- | -- | -- | -- | -- | -- | -- | -- |
# |55 | 方元寀 | 程颐 | 0203 | Intellectual Affiliations | 學術交往 | positive | In the paragraph, it is mentioned that 方元寀 (a) and 程颐 (b) had interactions through letters ("书问往复，至数十纸"). This shows that they had an intellectual affiliation, which corresponds to the association type 0203 - Intellectual Affiliations (學術交往). The relationship can be considered positive as 程颐 praised 方元寀 for his loyalty and dedication to the path of truth ("足下非混俗之流，其忠道之士"). |

# %%
number_of_inputs = 5
df1 = pd.read_csv('song.csv')
df1 = df1[df1['name_number'] >= 2]
paragraphs = df1.values.tolist()

for i in range(0, 10, number_of_inputs):
    prompt_out = prompt_head
    paragraph_list = paragraphs[i:i+number_of_inputs]
    for paragraph in paragraph_list:
        paragraph_number = paragraph[0]
        text = paragraph[1]
        people_num = paragraph[3]
        people = paragraph[2].split(",")
        alphabet = "abcdefghi"
        prompt2 = ' it mentions '
        for i in range(people_num):
            prompt2 += "[" + alphabet[i] + "]" + '"' + people[i] + '", '
        prompt2 = prompt2[:-2]
        prompt = 'Task number is {}. The biography is "{}",'.format(paragraph_number, text)
        prompt_out += prompt + prompt2 + "\n"
    #print(prompt_out)

# %%
for res in result:
    print(res)
# Out:
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 1 | 丁元 | - | - | - | - | No other person mentioned in the biography |
# | 2 | 丁中 | 徐鹿卿 | 0103; 0203 | 社會交際; 學術交往 | positive | They are described as friends and share academic interests |
# | 2 | 丁中 | 吴澄 | 0103; 0203 | 社會交際; 學術交往 | positive | They are described as friends and share academic interests |
# | 3 | 丁氏 | 张晋卿 | 0901 | 家庭關係（籠統） | positive | 丁氏 is the wife of 张晋卿 |
# | 4 | 丁石 | 戴复古 | 0103; 0207 | 社會交際; 文學藝術交往 | positive | They are described as friends and share literary interests |
# | 5 | 丁木 | 叶适 | 0202; 0203 | 師生關係; 學術交往 | positive | 丁木 studied under 叶适 and they share academic interests |
# | 5 | 丁木 | 松山先生 | - | - | - | 松山先生 is another name for 丁木, not a separate person |
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# ...

# %% [markdown]
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 1 | 丁元 | - | - | - | - | No other person mentioned in the biography |
# | 2 | 丁中 | 徐鹿卿 | 0103; 0203 | 社會交際; 學術交往 | positive | They are described as friends and share academic interests |
# | 2 | 丁中 | 吴澄 | 0103; 0203 | 社會交際; 學術交往 | positive | They are described as friends and share academic interests |
# | 3 | 丁氏 | 张晋卿 | 0901 | 家庭關係（籠統） | positive | 丁氏 is the wife of 张晋卿 |
# | 4 | 丁石 | 戴复古 | 0103; 0207 | 社會交際; 文學藝術交往 | positive | They are described as friends and share literary interests |
# | 5 | 丁木 | 叶适 | 0202; 0203 | 師生關係; 學術交往 | positive | 丁木 studied under 叶适 and they share academic interests |
# | 5 | 丁木 | 松山先生 | - | - | - | 松山先生 is another name for 丁木, not a separate person |
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | 27 | 万俟卨 | 岳飞 | 0403; 0603 | 官場關係（下屬）; 軍事對抗 | negative | 岳飞宣抚荆湖，过卨，不以礼，卨憾之。入观，希秦桧意，谮飞，构陷成狱，飞父子与张宪俱死，天下冤之 |
# | 27 | 万俟卨 | 秦桧 | 0404 | 官場關係（上司） | positive | 万俟卨希秦桧意，谮岳飞，表示他们有官场关系，且卨迎合秦桧的意图 |
# | 27 | 万俟卨 | 张宪 | 0403 | 官場關係（下屬） | negative | 万俟卨构陷成狱，岳飞父子与张宪俱死，表示他们有官场关系，且卨对张宪有负面影响 |
# | 28 | 于洋 | 李全 | 0601; 0602 | 軍事關係（籠統）; 軍事支持 | positive | 于洋为李全部将，开禧间曾攻克密州，有战功，表示他们有军事关系，且于洋在战斗中支持李全 |
# | 29 | 于格 | 冯时行 | 0103; 0207 | 社會交際; 文學藝術交往 | positive | 于格与冯时行为友，同游十五人，访古梅于成都西郊，分韵赋诗，表示他们有社交关系，且在文学艺术方面有交流 |
# | 30 | 于宪 | 张九成 | 0202; 0203 | 師生關係; 學術交往 | positive | 于宪承舅氏张九成之教，表示他们有师生关系，且在学术方面有交流 |
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 31 | 于兴 | 李芾 | 0601; 0602 | 軍事關係（籠統）; 軍事支持 | positive | 于兴是李芾的部将，德祐元年，元兵攻潭州，芾命兴帅兵御之 |
# | 32 | 于焘 | 吕夷简 | 0401; 0402 | 政治關係（籠統）; 官場關係（平級） | positive | 丞相吕夷简召焘计之，焘提出建议，后事实证明焘的建议有效 |
# | 32 | 于焘 | 仁宗 | 0401 | 政治關係（籠統） | positive | 于焘上疏建议仁宗早定储位，以安天下 |
# | 32 | 于焘 | 英宗 | 0401 | 政治關係（籠統） | positive | 于焘预测英宗入继，人们服其先识 |
# | 33 | 于世封 | 欧阳修 | 0202; 0203 | 師生關係; 學術交往 | positive | 于世封见欧阳修，修授以为文之道，于世封自惭前傲，学益精进 |
# | 34 | 士建中 | 孙复 | 0203; 0204 | 學術交往; 學術主題相近 | positive | 士建中与孙复、石介同时以学鸣于当世，为孙石二氏所推重 |
# | 34 | 士建中 | 石介 | 0203; 0204 | 學術交往; 學術主題相近 | positive | 士建中与孙复、石介同时以学鸣于当世，为孙石二氏所推重 |
# | 35 | 上官冲 | 周慎 | 0103 | 社會交際 | positive | 上官冲与进士周慎同游华岳，刻石以记 |
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 36 | 上官均 | 哲宗 | 0404 | 官場關係（上司） | positive | 上官均在哲宗時為御史，遇事敢言 |
# | 36 | 上官均 | 蔡确 | 0407 | 政治對抗 | negative | 上官均劾去蔡确 |
# | 36 | 上官均 | 张璪 | 0407 | 政治對抗 | negative | 上官均劾去张璪 |
# | 36 | 上官均 | 李清臣 | 0407 | 政治對抗 | negative | 上官均劾去李清臣 |
# | 36 | 上官均 | 徽宗 | 0404 | 官場關係（上司） | negative | 徽宗立，上官均遷給事中，但後入黨籍奪職 |
# | 51 | 方壬 | 朱熹 | 0202; 0203; 0206 | 師生關係; 學術交往; 學術襄助 | positive | 方壬 was appointed by 朱熹 to be in charge of the school and discussed various academic matters |
# | 52 | 方禾 | 朱熹 | 0202; 0203 | 師生關係; 學術交往 | positive | 方禾 was a student of 朱熹 and admired his teachings on self-improvement |
# | 53 | 方回 | 贾似道 | 0407 | 政治對抗 | negative | 方回 initially supported 贾似道, but 贾似道 later accused him, leading to a negative relationship |
# | 54 | 方耒 | 张栻 | 0402; 0406 | 官場關係（平級）; 薦舉保任 | positive | 张栻 admired 方耒 and considered him a trustworthy ally, later recommending him for a position |
# | 55 | 方价 | 蔡京 | 0407 | 政治對抗 | negative | 蔡京 disapproved of 方价 for not paying private visits and reported him, leading to a negative relationship |
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 56 | 方宙 | 章惇 | 0406 | 薦舉保任 | positive | 章惇推荐方宙 |
# | 56 | 方宙 | 蔡确 | 0406 | 薦舉保任 | positive | 蔡确推荐方宙 |
# | 56 | 方宙 | 蔡京 | 0406 | 薦舉保任 | positive | 蔡京推荐方宙 |
# | 56 | 方宙 | 程颐 | 0501 | 著述關係（籠統） | positive | 方宙请求给还程颐旧田 |
# | 56 | 方宙 | 范镇子 | 0501 | 著述關係（籠統） | positive | 方宙为范镇子论奏 |
# | 57 | 方来 | 叶适 | 0202; 0203 | 師生關係; 學術交往 | positive | 方来从叶适学习 |
# | 57 | 方来 | 黄榦 | 0202; 0203 | 師生關係; 學術交往 | positive | 方来从黄榦学习 |
# | 58 | 方岳 | 赵葵 | 0403 | 官場關係（上司） | positive | 方岳为赵葵参议官 |
# | 58 | 方岳 | 贾似道 | 0403; 0407 | 官場關係（上司）; 政治對抗 | negative | 方岳因忤贾似道而受罚 |
# | 58 | 方岳 | 丁大全 | 0403; 0407 | 官場關係（上司）; 政治對抗 | negative | 方岳因忤丁大全而罢归 |
# | 59 | 方洪 | 赵与择 | 0601; 0603 | 軍事關係（籠統）; 軍事對抗 | negative | 方洪与赵与择共同防御元兵，城陷后被俘，均不屈而死 |
# | 60 | 方恬 | 周必大 | 0406 | 薦舉保任 | positive | 周必大推荐方恬 |
# | 60 | 方恬 | 李焘 | 0406 | 薦舉保任 | positive | 李焘推荐方恬 |
# | 60 | 方恬 | 程大昌 | 0406 | 薦舉保任 | positive | 程大昌推荐方恬 |
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 61 | 方适 | 孙 | 0202 | 師生關係 | positive | 方适 is 孙's student (慎言从孙) |
# | 62 | 方淑 | 秦桧 | 0407 | 政治對抗 | negative | 方淑 did not agree with 秦桧's ideas and was dismissed from office (不附秦桧意罢官) |
# | 63 | 方淙 | 行简 | 0202 | 師生關係 | positive | 方淙 passed the exam under 行简's guidance (傅行简榜进士) |
# | 64 | 方通 | 子轸 | 0901 | 家庭關係（籠統） | positive | 方通 is 子轸's father (坐子轸上书论列蔡京谪官) |
# | 64 | 方通 | 蔡京 | 0407 | 政治對抗 | negative | 方通's son 子轸 criticized 蔡京, leading to 方通's demotion (坐子轸上书论列蔡京谪官) |
# | 65 | 方轸 | 蔡京 | 0407 | 政治對抗 | negative | 方轸 criticized 蔡京's crimes (上书论蔡京罪) |
# Task 66:
#
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 66 | 方棐 | 王迈 | 0203; 0503 | 学术交往; 墓誌文字 | positive | 方棐从王迈游学，且请王迈为其父撰写墓志 |
#
# Task 67:
#
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 67 | 方溥 | 杨简 | 0103 | 社會交際 | positive | 杨简誉方溥为诚确正直 |
#
# Task 68:
#
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 68 | 方端 | 欧阳修 | 0206 | 学术襄助 | positive | 方端因文行受欧阳修器重 |
#
# Task 69:
#
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 69 | 方瑑 | 张居卿 | 0301 | 朋友關係（籠統） | positive | 方瑑与张居卿关系最厚善 |
#
# Task 70:
#
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 70 | 方谊 | 朱熹 | 0202 | 師生關係 | positive | 方谊向朱熹请教学问，被朱熹称赞 |
# | [task no] | [person 1] | [person 2] | [assoc_code] | [assoc_chn] | [positive/negative relationship] | [reasoning] |
# | -- | -- | -- | -- | -- | -- | -- |
# | 71 | 方輗 | 李燔 | 0202 | 師生關係 | positive | 受业李燔 indicates that 方輗 was a student of 李燔 |
# | 71 | 方輗 | 饶伯舆 | 0301 | 朋友關係（籠統） | positive | 与饶伯舆友善 indicates that 方輗 and 饶伯舆 had a friendly relationship |
# | 71 | 方輗 | 魏了翁 | 0206 | 學術襄助 | positive | 参政魏了翁嘉其学行 indicates that 魏了翁 appreciated 方輗's academic achievements |
# | 72 | 方泽 | 黄庭坚 | 0207 | 文學藝術交往 | positive | 多与黄庭坚唱和 indicates that 方泽 and 黄庭坚 had a literary/artistic exchange |
# | 73 | 方导 | 张九成 | 0202 | 師生關係 | positive | 师承张九成 indicates that 方导 was a student of 张九成 |
# | 73 | 方导 | 范光远 | 0203 | 學術交往 | positive | 又从范光远游 indicates that 方导 had academic interactions with 范光远 |
# | 73 | 方导 | 林之奇 | 0203 | 學術交往 | positive | 又从林之奇游 indicates that 方导 had academic interactions with 林之奇 |
# | 74 | 方兴 | 张世杰 | 0602 | 軍事支持 | positive | 与张世杰共图恢复 indicates that 方兴 and 张世杰 cooperated in military efforts |
# | 74 | 方兴 | 文天祥 | 0602 | 軍事支持 | positive | 与文天祥共图恢复 indicates that 方兴 and 文天祥 cooperated in military efforts |
# | 75 | 方晔 | 郑樵 | 0206 | 學術襄助 | positive | 郑樵称其文高于天下，行高于乡闾 indicates that 郑樵 praised 方晔's literary achievements and conduct |
